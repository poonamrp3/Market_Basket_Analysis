# %% [markdown]
# # Market Basket Analysis

# %% [markdown]
# In this tutorial, we will explore the Market Basket Analysis dataset, which can be downloaded from Kaggle using the following link: Market Basket Analysis Dataset.
#
# We will start by performing data cleaning to ensure the dataset is ready for analysis. Next, we will extract frequent itemsets using the FP-Growth algorithm, a powerful tool for mining frequent patterns in large datasets. Additionally, we will analyze the frequent itemsets on a per-country basis, enabling us to uncover unique purchasing patterns and trends across different regions.
#
# By the end of this tutorial, you will have a solid understanding of how to preprocess transactional data and use the FP-Growth algorithm to gain valuable insights into customer purchasing behavior.

# %% [markdown]
# Before we begin, we have to install pandas and mlxtend to run queries on the data and run the FPGrowth algorithm.
# We also have to install neo4j, networkx, and matplotlib for data visualization of the results.
#
# To install pandas, mlxtend, neo4j, networkx, and matplotlib with pip:

# %% [markdown]
# ```bash
# pip install pandas
# pip install mlxtend==0.23.1
# pip install neo4j
# pip install networkx
# pip install matplotlib

# %% [markdown]
# # Importing Data

# %% [markdown]
# Once the libraries have been installed, we can start to import data into our program. There are multiple ways of importing the data such as using the Kaggle API or downloading the csv file. In this tutorial, we will be using the downloaded folder provided in kaggle and renaming the folder to `data`. The file path is shown below in the variable `FILE` and can be modified to your liking.
#
# When importing the csv file with pandas, there is some inconsistent data present as a result of poor formatting. Since only a small number of rows are affected by this, we decided to just skip the rows and still retain a large portion of the data.

# %%
import pandas as pd

FILE = "./data/Assignment-1_Data.csv"

data = pd.read_csv(FILE, sep=";", on_bad_lines="skip", low_memory=False)

print(data.head())
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# 2  2,75     17850.0  United Kingdom
# 3  3,39     17850.0  United Kingdom
# 4  3,39     17850.0  United Kingdom

# %% [markdown]
# # Cleaning Data

# %% [markdown]
# In this step, we will clean the dataset by focusing on the columns that are most relevant to our analysis: `BillNo`, `Itemname`, and `Country`. All other columns will be dropped, as they are not necessary for the insights we aim to extract. Next, we will remove any entries where the data is incomplete, specifically rows where `BillNo`, `Itemname`, or `Country` are missing. These incomplete records can introduce inconsistencies or inaccuracies in our analysis, so it is important to exclude them. Additionally, we will clean up the Itemname column by removing any leading or trailing whitespace to ensure consistency and accuracy when analyzing item names. These preprocessing steps will ensure that the dataset is clean, focused, and ready for further analysis.

# %%
columns_to_keep = ['BillNo', 'Itemname', 'Country']

data = data[columns_to_keep]

#Drop rows with missing values
data.dropna(inplace=True)

data['Itemname'] = data['Itemname'].str.strip()

print(data.head())
# Out:
#    BillNo                             Itemname         Country
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# 1  536365                  WHITE METAL LANTERN  United Kingdom
# 2  536365       CREAM CUPID HEARTS COAT HANGER  United Kingdom
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE  United Kingdom
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.  United Kingdom

# %% [markdown]
# To analyze transactions across different regions, we separate the data by country. This is achieved by creating a dictionary called `country_datas`, which leverages the groupby function to group all rows based on the `Country` column. Each country serves as a key in the dictionary, with its corresponding value being a subset of the data containing only transactions for that specific country. However, there are transactions with a `Country` of `Undefined` which we will exclude from our data. To maintain accuracy of our results, we only keep the countries where there are at least 1000 rows of transactional data.
#
# Finally, a quick preview of the transactions for each country is displayed which can be commented out.

# %%
country_datas = {country: data for country, data in data.groupby('Country')}
    
del country_datas["Unspecified"]

# Keep countries with more than 2000 rows of transaction details 
country_datas = {key: value for key, value in country_datas.items() if value.shape[0] > 1000}

for country, data in country_datas.items():
        print(f"Data for {country}:")
        print(data.head()) 
        print("\n")
# Out:
# Data for Australia:
#      BillNo                           Itemname    Country
# 195  536389       CHRISTMAS LIGHTS 10 REINDEER  Australia
# 196  536389   VINTAGE UNION JACK CUSHION COVER  Australia
# 197  536389  VINTAGE HEADS AND TAILS CARD GAME  Australia
# 198  536389    SET OF 3 COLOURED  FLYING DUCKS  Australia
# 199  536389         SET OF 3 GOLD FLYING DUCKS  Australia
#
#
# Data for Belgium:
#       BillNo                            Itemname  Country
# 7088  537026       SET OF 20 KIDS COOKIE CUTTERS  Belgium
# 7089  537026       RED RETROSPOT ROUND CAKE TINS  Belgium
# 7090  537026     PACK OF 72 RETROSPOT CAKE CASES  Belgium
# 7091  537026  PACK OF 60 PINK PAISLEY CAKE CASES  Belgium
# 7092  537026      PACK OF 60 SPACEBOY CAKE CASES  Belgium
#
#
# Data for France:
#     BillNo                         Itemname Country
# 26  536370        ALARM CLOCK BAKELIKE PINK  France
# 27  536370         ALARM CLOCK BAKELIKE RED  France
# 28  536370       ALARM CLOCK BAKELIKE GREEN  France
# 29  536370  PANDA AND BUNNIES STICKER SHEET  France
# 30  536370                  STARS GIFT TAPE  France
#
#
# Data for Germany:
#       BillNo                             Itemname  Country
# 1099  536527              SET OF 6 T-LIGHTS SANTA  Germany
# 1100  536527  ROTATING SILVER ANGELS T-LIGHT HLDR  Germany
# 1101  536527   MULTI COLOUR SILVER T-LIGHT HOLDER  Germany
# 1102  536527        5 HOOK HANGER MAGIC TOADSTOOL  Germany
# 1103  536527           3 HOOK HANGER MAGIC GARDEN  Germany
#
#
# Data for Netherlands:
#        BillNo                          Itemname      Country
# 376    536403           HAND WARMER BIRD DESIGN  Netherlands
# 377    536403                           POSTAGE  Netherlands
# 36881  539491       PACK OF 12 WOODLAND TISSUES  Netherlands
# 36882  539491  PACK OF 12 PINK POLKADOT TISSUES  Netherlands
# 36883  539491  SET OF 3 CAKE TINS PANTRY DESIGN  Netherlands
#
#
# Data for Norway:
#       BillNo                       Itemname Country
# 1226  536532    BOX OF 24 COCKTAIL PARASOLS  Norway
# 1227  536532   GROW YOUR OWN PLANT IN A CAN  Norway
# 1228  536532    CHILDREN'S APRON DOLLY GIRL  Norway
# 1229  536532      RETROSPOT CHILDRENS APRON  Norway
# 1230  536532  PLASTERS IN TIN CIRCUS PARADE  Norway
#
#
# Data for Portugal:
#       BillNo                        Itemname   Country
# 6944  536990  VINTAGE PAISLEY STATIONERY SET  Portugal
# 6945  536990          LUNCH BAG SUKI  DESIGN  Portugal
# 6946  536990             LUNCH BAG CARS BLUE  Portugal
# 6947  536990       RED RETROSPOT LUGGAGE TAG  Portugal
# 6948  536990           RED HEART LUGGAGE TAG  Portugal
#
#
# Data for Spain:
#       BillNo                 Itemname Country
# 6305  536944   LUNCH BAG SUKI  DESIGN   Spain
# 6306  536944  LUNCH BAG PINK POLKADOT   Spain
# 6307  536944  LUNCH BAG  BLACK SKULL.   Spain
# 6308  536944  LUNCH BAG RED RETROSPOT   Spain
# 6309  536944      LUNCH BAG CARS BLUE   Spain
#
#
# Data for Switzerland:
#       BillNo                            Itemname      Country
# 5218  536858  ROUND SNACK BOXES SET OF4 WOODLAND  Switzerland
# 5219  536858    PLASTERS IN TIN WOODLAND ANIMALS  Switzerland
# 5220  536858       RED TOADSTOOL LED NIGHT LIGHT  Switzerland
# 5221  536858                  PINK POLKADOT BOWL  Switzerland
# 5222  536858            RED RETROSPOT MINI CASES  Switzerland
#
#
# Data for United Kingdom:
#    BillNo                             Itemname         Country
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# 1  536365                  WHITE METAL LANTERN  United Kingdom
# 2  536365       CREAM CUPID HEARTS COAT HANGER  United Kingdom
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE  United Kingdom
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.  United Kingdom

# %% [markdown]
# In our current dataset, we have `country_data`, which contains transactions for each country, organized by `BillNo`. To prepare the data for frequent itemset mining, we need to group all transactions sharing the same BillNo into a single transaction. This ensures that all items purchased together in the same transaction are treated as a single unit. We achieve this by using the `groupby` function to aggregate the items by `BillNo`, effectively combining them into grouped transactions.
#
# Examples of our transactions can be ran in the following print statements to have a close look. After this transformation, out transactions data for each country is now ready for the `TransactionEncoder` in `mlxtend`.

# %%
country_transactions = {}

for country, data in country_datas.items():
    country_transactions[country] = data.groupby(['BillNo'])['Itemname'].apply(lambda x: ','.join(x)).reset_index()
        
for country, transactions in country_transactions.items():
    transactions.drop(columns=['BillNo'], inplace=True)
    transactions.rename(columns={'Itemname': 'Items'}, inplace=True)
    
for country, transactions in country_transactions.items():
    print(f"Transactions for {country}:")
    print(transactions.head()) 
    print("\n")
    
for country, transactions in country_transactions.items():
    country_transactions[country] = transactions['Items'].apply(lambda x: x.split(',')).tolist()
    
for country, transactions in country_transactions.items():
    print(f"Transactions for {country}:")
    print(transactions[0]) 
    print("\n")
# Out:
# Transactions for Australia:
#                                                Items
# 0  CHRISTMAS LIGHTS 10 REINDEER,VINTAGE UNION JAC...
# 1  20 DOLLY PEGS RETROSPOT,ASSORTED BOTTLE TOP  M...
# 2  DOORMAT UNION FLAG,CORONA MEXICAN TRAY,LUNCH B...
# 3  RIBBON REEL LACE DESIGN,RIBBON REEL HEARTS DES...
# 4          PORCELAIN ROSE SMALL,PORCELAIN ROSE LARGE
#
#
# Transactions for Belgium:
#                                                Items
# 0  SET OF 20 KIDS COOKIE CUTTERS,RED RETROSPOT RO...
# 1  ANTIQUE GLASS PEDESTAL BOWL,VINTAGE CREAM CAT ...
# 2  DOLLY GIRL LUNCH BOX,RED RETROSPOT TAPE,HEARTS...
# 3  DOORMAT RED RETROSPOT,PAPERWEIGHT CHILDHOOD ME...
# 4  SET/10 RED POLKADOT PARTY CANDLES,SET/10 PINK ...
#
#
# Transactions for France:
#                                                Items
# 0  ALARM CLOCK BAKELIKE PINK,ALARM CLOCK BAKELIKE...
# 1  PICTURE DOMINOES,MINI JIGSAW SPACEBOY,MINI JIG...
# 2  EDWARDIAN PARASOL BLACK,EDWARDIAN PARASOL PINK...
# 3  HOT WATER BOTTLE BABUSHKA,BREAD BIN DINER STYL...
# 4  JAM MAKING SET PRINTED,SET/4 SKULL BADGES,ROUN...
#
#
# Transactions for Germany:
#                                                Items
# 0  SET OF 6 T-LIGHTS SANTA,ROTATING SILVER ANGELS...
# 1  JAM MAKING SET PRINTED,JAM JAR WITH PINK LID,J...
# 2  FELTCRAFT 6 FLOWER FRIENDS,6 RIBBONS RUSTIC CH...
# 3                    POSTAGE,JUMBO BAG RED RETROSPOT
# 4  WOODLAND PARTY BAG + STICKER SET,HAND WARMER O...
#
#
# Transactions for Netherlands:
#                                                Items
# 0                    HAND WARMER BIRD DESIGN,POSTAGE
# 1  PACK OF 12 WOODLAND TISSUES,PACK OF 12 PINK PO...
# 2  PACK OF 72 RETROSPOT CAKE CASES,EASTER TIN KEE...
# 3  PACK OF 12 PINK POLKADOT TISSUES,ROSE COTTAGE ...
# 4  STRAWBERRY LUNCH BOX WITH CUTLERY,DINOSAUR LUN...
#
#
# Transactions for Norway:
#                                                Items
# 0  BOX OF 24 COCKTAIL PARASOLS,GROW YOUR OWN PLAN...
# 1  MAGIC DRAWING SLATE SPACEBOY,MAGIC DRAWING SLA...
# 2  CHOCOLATE THIS WAY METAL SIGN,METAL SIGN NEIGH...
# 3  WOODEN HAPPY BIRTHDAY GARLAND,PINK DOUGHNUT TR...
# 4  POSTAGE,DELUXE SEWING KIT,PINK HEART SHAPE EGG...
#
#
# Transactions for Portugal:
#                                                Items
# 0  VINTAGE PAISLEY STATIONERY SET,LUNCH BAG SUKI ...
# 1  3 STRIPEY MICE FELTCRAFT,FELTCRAFT DOLL ROSIE,...
# 2  HAND WARMER BIRD DESIGN,DOORMAT RED RETROSPOT,...
# 3  TRADITIONAL WOODEN SKIPPING ROPE,TRADITIONAL W...
# 4  LUNCH BAG CARS BLUE,LUNCH BAG SUKI  DESIGN,JUM...
#
#
# Transactions for Spain:
#                                                Items
# 0  LUNCH BAG SUKI  DESIGN,LUNCH BAG PINK POLKADOT...
# 1  CABIN BAG VINTAGE RETROSPOT,FOUR HOOK  WHITE L...
# 2  ROTATING SILVER ANGELS T-LIGHT HLDR,HOME SWEET...
# 3  JUMBO  BAG BAROQUE BLACK WHITE,JUMBO BAG RED R...
# 4  POSTAGE,CARD PARTY GAMES,PINK POLKADOT WRAP,SP...
#
#
# Transactions for Switzerland:
#                                                Items
# 0  ROUND SNACK BOXES SET OF4 WOODLAND,PLASTERS IN...
# 1  HOT WATER BOTTLE BABUSHKA LARGE,CHOCOLATE HOT ...
# 2  RED RETROSPOT TAPE,CUTE CATS TAPE,STARS GIFT T...
# 3  ROUND SNACK BOXES SET OF4 WOODLAND,ROUND SNACK...
# 4  STRAWBERRY HONEYCOMB  GARLAND,SMALL POPCORN HO...
#
#
# Transactions for United Kingdom:
#                                                Items
# 0  WHITE HANGING HEART T-LIGHT HOLDER,WHITE METAL...
# 1   HAND WARMER UNION JACK,HAND WARMER RED POLKA DOT
# 2  ASSORTED COLOUR BIRD ORNAMENT,POPPY'S PLAYHOUS...
# 3  JAM MAKING SET WITH JARS,RED COAT RACK PARIS F...
# 4                           BATH BUILDING BLOCK WORD
#
#
# Transactions for Australia:
# ['CHRISTMAS LIGHTS 10 REINDEER', 'VINTAGE UNION JACK CUSHION COVER', 'VINTAGE HEADS AND TAILS CARD GAME', 'SET OF 3 COLOURED  FLYING DUCKS', 'SET OF 3 GOLD FLYING DUCKS', 'RED RETROSPOT UMBRELLA', 'BLACK/BLUE POLKADOT UMBRELLA', 'RED DINER WALL CLOCK', 'ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED', 'BLUE DINER WALL CLOCK', 'IVORY DINER WALL CLOCK', 'LARGE HEART MEASURING SPOONS', 'SMALL HEART MEASURING SPOONS']
#
#
# Transactions for Belgium:
# ['SET OF 20 KIDS COOKIE CUTTERS', 'RED RETROSPOT ROUND CAKE TINS', 'PACK OF 72 RETROSPOT CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 60 SPACEBOY CAKE CASES', 'PACK OF 60 DINOSAUR CAKE CASES', 'PACK OF 60 MUSHROOM CAKE CASES', 'PLASTERS IN TIN SPACEBOY', 'JUMBO BAG RED RETROSPOT', 'CHARLOTTE BAG SUKI DESIGN', '72 SWEETHEART FAIRY CAKE CASES', 'POSTAGE']
#
#
# Transactions for France:
# ['ALARM CLOCK BAKELIKE PINK', 'ALARM CLOCK BAKELIKE RED', 'ALARM CLOCK BAKELIKE GREEN', 'PANDA AND BUNNIES STICKER SHEET', 'STARS GIFT TAPE', 'INFLATABLE POLITICAL GLOBE', 'VINTAGE HEADS AND TAILS CARD GAME', 'SET/2 RED RETROSPOT TEA TOWELS', 'ROUND SNACK BOXES SET OF4 WOODLAND', 'SPACEBOY LUNCH BOX', 'LUNCH BOX I LOVE LONDON', 'CIRCUS PARADE LUNCH BOX', 'CHARLOTTE BAG DOLLY GIRL DESIGN', 'RED TOADSTOOL LED NIGHT LIGHT', 'SET 2 TEA TOWELS I LOVE LONDON', 'VINTAGE SEASIDE JIGSAW PUZZLES', 'MINI JIGSAW CIRCUS PARADE', 'MINI JIGSAW SPACEBOY', 'MINI PAINT SET VINTAGE', 'POSTAGE']
#
#
# Transactions for Germany:
# ['SET OF 6 T-LIGHTS SANTA', 'ROTATING SILVER ANGELS T-LIGHT HLDR', 'MULTI COLOUR SILVER T-LIGHT HOLDER', '5 HOOK HANGER MAGIC TOADSTOOL', '3 HOOK HANGER MAGIC GARDEN', '5 HOOK HANGER RED MAGIC TOADSTOOL', 'ASSORTED COLOUR LIZARD SUCTION HOOK', 'JUMBO BAG WOODLAND ANIMALS', 'JUMBO BAG OWLS', 'HOT WATER BOTTLE BABUSHKA', 'HOMEMADE JAM SCENTED CANDLES', "CHILDREN'S CIRCUS PARADE MUG", 'PACK 3 FIRE ENGINE/CAR PATCHES', 'PICTURE DOMINOES', 'POSTAGE']
#
#
# Transactions for Netherlands:
# ['HAND WARMER BIRD DESIGN', 'POSTAGE']
#
#
# Transactions for Norway:
# ['BOX OF 24 COCKTAIL PARASOLS', 'GROW YOUR OWN PLANT IN A CAN', "CHILDREN'S APRON DOLLY GIRL", 'RETROSPOT CHILDRENS APRON', 'PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN STRONGMAN', 'PLASTERS IN TIN WOODLAND ANIMALS', 'PLASTERS IN TIN SKULLS', 'PLASTERS IN TIN SPACEBOY', 'MINI JIGSAW DINOSAUR', 'MINI JIGSAW SPACEBOY', 'MINI JIGSAW BAKE A CAKE', 'MINI JIGSAW CIRCUS PARADE', 'MINI JIGSAW DOLLY GIRL', 'MAGIC DRAWING SLATE SPACEBOY', 'MAGIC DRAWING SLATE DOLLY GIRL', 'MAGIC DRAWING SLATE CIRCUS PARADE', 'WOODEN SCHOOL COLOURING SET', 'PACK OF 12 TRADITIONAL CRAYONS', 'CARD PARTY GAMES', 'BOOZE & WOMEN GREETING CARD', 'FANCY FONT BIRTHDAY CARD', '', 'CARD CIRCUS PARADE', 'HAND WARMER SCOTTY DOG DESIGN', 'HAND WARMER RED RETROSPOT', 'HAND WARMER OWL DESIGN', 'HOT WATER BOTTLE TEA AND SYMPATHY', 'PACK OF 12 SUKI TISSUES', 'PACK OF 12 WOODLAND TISSUES', 'PACK OF 12 SKULL TISSUES', 'BLUE PAISLEY TISSUE BOX', 'PACK OF 12 BLUE PAISLEY TISSUES', 'PACK OF 12 CIRCUS PARADE TISSUES', 'PACK OF 12 RED RETROSPOT TISSUES', 'PACK OF 12 SPACEBOY TISSUES', 'LADS ONLY TISSUE BOX', 'RED RETROSPOT TISSUE BOX', 'PACK OF 12 PINK PAISLEY TISSUES', 'PLASTERS IN TIN VINTAGE PAISLEY', 'POLKADOT RAIN HAT', 'SET/20 RED RETROSPOT PAPER NAPKINS', 'JAM JAR WITH GREEN LID', 'JAM JAR WITH PINK LID', 'JAM MAKING SET PRINTED', 'SET OF 20 KIDS COOKIE CUTTERS', 'GINGERBREAD MAN COOKIE CUTTER', 'GIN AND TONIC MUG', "IF YOU CAN'T STAND THE HEAT MUG", 'I CAN ONLY PLEASE ONE PERSON MUG', '36 FOIL HEART CAKE CASES', 'PINK HEART SHAPE EGG FRYING PAN', '60 TEATIME FAIRY CAKE CASES', '72 SWEETHEART FAIRY CAKE CASES', 'PACK OF 72 SKULL CAKE CASES', 'PACK OF 60 PINK PAISLEY CAKE CASES', 'PACK OF 72 RETROSPOT CAKE CASES', 'LARGE POPCORN HOLDER', 'SMALL POPCORN HOLDER', '200 RED + WHITE BENDY STRAWS', 'RECIPE BOX RETROSPOT', 'RECIPE BOX PANTRY YELLOW DESIGN', 'RECIPE BOX BLUE SKETCHBOOK DESIGN', 'CLOTHES PEGS RETROSPOT PACK 24', '20 DOLLY PEGS RETROSPOT', 'LADIES & GENTLEMEN METAL SIGN', 'COOK WITH WINE METAL SIGN', 'HAND OVER THE CHOCOLATE   SIGN', 'NO SINGING METAL SIGN', 'RED HANGING HEART T-LIGHT HOLDER', 'DOORMAT RED RETROSPOT', 'BISCUIT TIN VINTAGE RED', 'EMERGENCY FIRST AID TIN', 'FIRST AID TIN']
#
#
# Transactions for Portugal:
# ['VINTAGE PAISLEY STATIONERY SET', 'LUNCH BAG SUKI  DESIGN', 'LUNCH BAG CARS BLUE', 'RED RETROSPOT LUGGAGE TAG', 'RED HEART LUGGAGE TAG', 'POSTAGE', 'LUNCH BAG WOODLAND']
#
#
# Transactions for Spain:
# ['LUNCH BAG SUKI  DESIGN', 'LUNCH BAG PINK POLKADOT', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT', 'LUNCH BAG CARS BLUE']
#
#
# Transactions for Switzerland:
# ['ROUND SNACK BOXES SET OF4 WOODLAND', 'PLASTERS IN TIN WOODLAND ANIMALS', 'RED TOADSTOOL LED NIGHT LIGHT', 'PINK POLKADOT BOWL', 'RED RETROSPOT MINI CASES', 'POSTAGE']
#
#
# Transactions for United Kingdom:
# ['WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE METAL LANTERN', 'CREAM CUPID HEARTS COAT HANGER', 'KNITTED UNION FLAG HOT WATER BOTTLE', 'RED WOOLLY HOTTIE WHITE HEART.', 'SET 7 BABUSHKA NESTING BOXES', 'GLASS STAR FROSTED T-LIGHT HOLDER']

# %% [markdown]
# # Generating Frequent Itemsets

# %% [markdown]
# To perform frequent itemset mining using the FP-Growth algorithm, we first prepared our data by transforming the `country_transactions` dictionary into a one-hot encoded format. The FP-Growth functions from the `mlxtend` library expect the input to be a binary matrix where each row represents a transaction, and columns represent the presence or absence of items. Using `TransactionEncoder` from `mlxtend.preprocessing`, we transformed each country's transaction data into a Pandas DataFrame with binary encoding.

# %%
from mlxtend.preprocessing import TransactionEncoder

for country, transactions in country_transactions.items():
    te = TransactionEncoder()
    te_ary = te.fit(transactions).transform(transactions)
    data = pd.DataFrame(te_ary, columns=te.columns_)
    country_transactions[country] = data
    
for country, transactions in country_transactions.items():
    print(f"Transactions for {country}:")
    print(transactions.head())
    print("\n")
# Out:
# Transactions for Australia:
#            1 HANGER    BIRTHDAY CARD   FRONT  DOOR   GARAGE DESIGN   SHED  \
# 0  False       False           False         False           False  False
# 1  False       False           False         False           False  False
# 2  False       False           False         False           False  False
# 3  False       False           False         False           False  False
# 4  False       False           False         False           False  False
#
#    10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False
#
#    12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  ...  \
# 0                      False                               False  ...
# 1                      False                               False  ...
# 2                      False                               False  ...
# 3                      False                               False  ...
# 4                      False                               False  ...
#
#    WRAP DOILEY DESIGN  WRAP DOLLY GIRL  WRAP ENGLISH ROSE  WRAP I LOVE LONDON  \
# 0               False            False              False               False
# 1               False            False              False               False
# 2               False            False              False               False
# 3               False            False              False               False
# 4               False            False              False               False
#
#    WRAP POPPIES  DESIGN  WRAP RED APPLES  WRAP RED VINTAGE DOILY  \
# 0                 False            False                   False
# 1                 False            False                   False
# 2                 False            False                   False
# 3                 False            False                   False
# 4                 False            False                   False
#
#    WRAP VINTAGE LEAF DESIGN  WRAP WEDDING DAY  YELLOW GIANT GARDEN THERMOMETER
# 0                     False             False                            False
# 1                     False             False                            False
# 2                     False             False                            False
# 3                     False             False                            False
# 4                     False             False                            False
#
# [5 rows x 615 columns]
#
#
# Transactions for Belgium:
#     1 HANGER    BREAKFAST IN BED   RETRO SPOT  12 COLOURED PARTY BALLOONS  \
# 0       False              False        False                       False
# 1       False              False        False                       False
# 2       False              False        False                       False
# 3       False              False        False                       False
# 4       False              False        False                       False
#
#    12 PENCIL SMALL TUBE WOODLAND  12 PENCILS SMALL TUBE RED RETROSPOT  \
# 0                          False                                False
# 1                          False                                False
# 2                          False                                False
# 3                          False                                False
# 4                           True                                 True
#
#    12 PENCILS SMALL TUBE SKULL  12 PENCILS TALL TUBE RED RETROSPOT  \
# 0                        False                               False
# 1                        False                               False
# 2                        False                               False
# 3                        False                               False
# 4                         True                               False
#
#    12 PENCILS TALL TUBE WOODLAND  200 BENDY SKULL STRAWS  ...  \
# 0                          False                   False  ...
# 1                          False                   False  ...
# 2                          False                   False  ...
# 3                          False                   False  ...
# 4                          False                    True  ...
#
#    WRAP DOLLY GIRL  WRAP ENGLISH ROSE  WRAP GINGHAM ROSE  WRAP MAGIC FOREST  \
# 0            False              False              False              False
# 1            False              False              False              False
# 2            False              False              False              False
# 3            False              False              False              False
# 4            False              False              False              False
#
#    WRAP MONSTER FUN  WRAP PAISLEY PARK  WRAP PINK FAIRY CAKES  \
# 0             False              False                  False
# 1             False              False                  False
# 2             False              False                  False
# 3             False              False                  False
# 4             False              False                  False
#
#    WRAP RED APPLES  WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
# [5 rows x 790 columns]
#
#
# Transactions for France:
#            BACK DOOR   BIRTHDAY CARD   CHOCOLATE  SPOTS   NEW ENGLAND  \
# 0  False       False           False              False         False
# 1  False       False           False              False         False
# 2  False       False           False              False         False
# 3  False       False           False              False         False
# 4   True       False           False              False         False
#
#     OVERCROWDED POOL.   RETRO SPOT   SHED  10 COLOUR SPACEBOY PEN  \
# 0               False        False  False                   False
# 1               False        False  False                   False
# 2               False        False  False                   False
# 3               False        False  False                   False
# 4               False        False  False                   False
#
#    12 COLOURED PARTY BALLOONS  ...  WRAP VINTAGE PETALS  DESIGN  \
# 0                       False  ...                        False
# 1                       False  ...                        False
# 2                       False  ...                        False
# 3                       False  ...                        False
# 4                       False  ...                        False
#
#    YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# 0                           False                            False
# 1                           False                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                            False
#
#    YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
#
#    ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                       False
#
#    ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    ZINC T-LIGHT HOLDER STARS SMALL
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
# [5 rows x 1575 columns]
#
#
# Transactions for Germany:
#            1 HANGER    BILLBOARD FONTS DESIGN   BIRTHDAY CARD  \
# 0  False       False                    False           False
# 1  False       False                    False           False
# 2  False       False                    False           False
# 3  False       False                    False           False
# 4  False       False                    False           False
#
#     OVERCROWDED POOL.   RETRO SPOT  10 COLOUR SPACEBOY PEN  \
# 0               False        False                   False
# 1               False        False                   False
# 2               False        False                   False
# 3               False        False                   False
# 4               False        False                   False
#
#    12 COLOURED PARTY BALLOONS  12 IVORY ROSE PEG PLACE SETTINGS  \
# 0                       False                             False
# 1                       False                             False
# 2                       False                             False
# 3                       False                             False
# 4                       False                             False
#
#    12 MESSAGE CARDS WITH ENVELOPES  ...  YULETIDE IMAGES GIFT WRAP SET  \
# 0                            False  ...                          False
# 1                            False  ...                          False
# 2                            False  ...                          False
# 3                            False  ...                          False
# 4                            False  ...                          False
#
#    ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  ZINC BOX SIGN HOME  \
# 0                       False                      False               False
# 1                       False                      False               False
# 2                       False                      False               False
# 3                       False                      False               False
# 4                       False                      False               False
#
#    ZINC FOLKART SLEIGH BELLS  ZINC HEART LATTICE T-LIGHT HOLDER  \
# 0                      False                              False
# 1                      False                              False
# 2                      False                              False
# 3                      False                              False
# 4                      False                              False
#
#    ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                            False                             False
#
# [5 rows x 1710 columns]
#
#
# Transactions for Netherlands:
#            1 HANGER    BIRTHDAY CARD   PINK  SPOTS   RETRO SPOT  \
# 0  False       False           False         False        False
# 1  False       False           False         False        False
# 2  False       False           False          True        False
# 3   True       False            True         False        False
# 4  False        True           False         False        False
#
#    10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# 0                   False                          False
# 1                   False                          False
# 2                   False                          False
# 3                   False                          False
# 4                   False                          False
#
#    12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS TALL TUBE RED RETROSPOT  \
# 0                                False                               False
# 1                                False                               False
# 2                                False                               False
# 3                                False                               False
# 4                                False                               False
#
#    12 PENCILS TALL TUBE WOODLAND  ...  WRAP RED APPLES  WRAP WEDDING DAY  \
# 0                          False  ...            False             False
# 1                          False  ...            False             False
# 2                          False  ...            False             False
# 3                          False  ...            False             False
# 4                          False  ...            False             False
#
#    YELLOW METAL CHICKEN HEART  ZINC  HEART T-LIGHT HOLDER  \
# 0                       False                       False
# 1                       False                       False
# 2                        True                       False
# 3                       False                       False
# 4                       False                       False
#
#    ZINC  STAR T-LIGHT HOLDER  ZINC FOLKART SLEIGH BELLS  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
#
#    ZINC T-LIGHT HOLDER STARS SMALL  ZINC WILLIE WINKIE  CANDLE STICK
# 0                            False                             False
# 1                            False                             False
# 2                            False                             False
# 3                            False                             False
# 4                            False                             False
#
# [5 rows x 812 columns]
#
#
# Transactions for Norway:
#           10 COLOUR SPACEBOY PEN  12 PENCILS TALL TUBE SKULLS  \
# 0   True                   False                        False
# 1   True                   False                        False
# 2  False                   False                        False
# 3  False                   False                        False
# 4  False                   False                        False
#
#    12 PENCILS TALL TUBE WOODLAND  20 DOLLY PEGS RETROSPOT  \
# 0                          False                     True
# 1                          False                     True
# 2                          False                    False
# 3                          False                    False
# 4                          False                    False
#
#    200 RED + WHITE BENDY STRAWS  3 HOOK PHOTO SHELF ANTIQUE WHITE  \
# 0                          True                             False
# 1                          True                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
#
#    3 PIECE SPACEBOY COOKIE CUTTER SET  3 TRADITIONAl BISCUIT CUTTERS  SET  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
#
#    36 DOILIES DOLLY GIRL  ...  WOODLAND STORAGE BOX SMALL  \
# 0                  False  ...                       False
# 1                  False  ...                       False
# 2                  False  ...                       False
# 3                  False  ...                       False
# 4                  False  ...                       False
#
#    WORLD WAR 2 GLIDERS ASSTD DESIGNS  WRAP 50'S  CHRISTMAS  \
# 0                              False                 False
# 1                              False                 False
# 2                              False                 False
# 3                              False                 False
# 4                              False                 False
#
#    YELLOW COAT RACK PARIS FASHION  YOU'RE CONFUSING ME METAL SIGN  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    ZINC HEART FLOWER T-LIGHT HOLDER  ZINC HEART LATTICE CHARGER LARGE  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# 0                           False                            False
# 1                           False                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                            False
#
#    ZINC WILLIE WINKIE  CANDLE STICK
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
# [5 rows x 599 columns]
#
#
# Transactions for Portugal:
#           10 COLOUR SPACEBOY PEN  12 PENCIL SMALL TUBE WOODLAND  \
# 0  False                   False                          False
# 1  False                   False                          False
# 2  False                   False                          False
# 3  False                   False                          False
# 4  False                   False                          False
#
#    12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS TALL TUBE POSY  \
# 0                                False                      False
# 1                                False                      False
# 2                                False                      False
# 3                                False                      False
# 4                                False                      False
#
#    12 PENCILS TALL TUBE RED RETROSPOT  12 PENCILS TALL TUBE WOODLAND  \
# 0                               False                          False
# 1                               False                          False
# 2                               False                          False
# 3                               False                          False
# 4                               False                          False
#
#    20 DOLLY PEGS RETROSPOT  3 PIECE SPACEBOY COOKIE CUTTER SET  \
# 0                    False                               False
# 1                    False                               False
# 2                    False                               False
# 3                    False                               False
# 4                    False                               False
#
#    3 STRIPEY MICE FELTCRAFT  ...  WRAP FLOWER SHOP  WRAP GINGHAM ROSE  \
# 0                     False  ...             False              False
# 1                      True  ...             False              False
# 2                     False  ...             False              False
# 3                     False  ...             False              False
# 4                     False  ...             False              False
#
#    WRAP PAISLEY PARK  WRAP PINK FAIRY CAKES  WRAP RED APPLES  \
# 0              False                  False            False
# 1              False                  False            False
# 2              False                  False            False
# 3              False                  False            False
# 4              False                  False            False
#
#    WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# 0                   False                  False
# 1                   False                  False
# 2                   False                  False
# 3                   False                  False
# 4                   False                  False
#
#    YOU'RE CONFUSING ME METAL SIGN  ZINC FOLKART SLEIGH BELLS  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
#
#    ZINC WIRE KITCHEN ORGANISER
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
#
# [5 rows x 717 columns]
#
#
# Transactions for Spain:
#            BILLBOARD FONTS DESIGN   BREAKFAST IN BED   DOUGHNUTS  \
# 0  False                    False              False       False
# 1  False                    False              False       False
# 2   True                    False              False       False
# 3  False                    False              False       False
# 4  False                    False              False       False
#
#     NEW ENGLAND   RETRO SPOT   STICKY GORDON   TWO SISTERS.  \
# 0         False        False           False          False
# 1         False        False           False          False
# 2         False         True           False          False
# 3         False        False           False          False
# 4         False        False            True           True
#
#    10 COLOUR SPACEBOY PEN  12 EGG HOUSE PAINTED WOOD  ...  WRAP PAISLEY PARK  \
# 0                   False                      False  ...              False
# 1                   False                      False  ...              False
# 2                   False                      False  ...              False
# 3                   False                      False  ...              False
# 4                   False                      False  ...              False
#
#    WRAP RED APPLES  WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
#    YELLOW COAT RACK PARIS FASHION  YELLOW FLOWERS FELT HANDBAG KIT  \
# 0                           False                            False
# 1                            True                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                             True
#
#    ZINC FOLKART SLEIGH BELLS  ZINC METAL HEART DECORATION  \
# 0                      False                        False
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#    ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL
# 0                           False                            False
# 1                           False                            False
# 2                           False                            False
# 3                           False                            False
# 4                           False                            False
#
# [5 rows x 1115 columns]
#
#
# Transactions for Switzerland:
#            BIRTHDAY CARD   BREAKFAST IN BED   RETRO SPOT  \
# 0  False           False              False        False
# 1   True           False              False        False
# 2   True            True              False        False
# 3  False           False              False        False
# 4  False           False              False        False
#
#    10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# 0                   False                       False
# 1                   False                       False
# 2                   False                       False
# 3                   False                       False
# 4                   False                       False
#
#    12 PENCIL SMALL TUBE WOODLAND  12 PENCILS SMALL TUBE SKULL  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                           True                        False
# 4                          False                        False
#
#    12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  ...  \
# 0                      False                               False  ...
# 1                      False                               False  ...
# 2                      False                               False  ...
# 3                      False                               False  ...
# 4                      False                               False  ...
#
#    WRAP MAGIC FOREST  WRAP PAISLEY PARK  WRAP PINK FAIRY CAKES  \
# 0              False              False                  False
# 1              False              False                  False
# 2              False              False                  False
# 3              False              False                  False
# 4              False              False                  False
#
#    WRAP RED APPLES  WRAP RED VINTAGE DOILY  WRAP SUKI AND FRIENDS  \
# 0            False                   False                  False
# 1            False                   False                  False
# 2            False                   False                  False
# 3            False                   False                  False
# 4            False                   False                  False
#
#    YELLOW METAL CHICKEN HEART  YOU'RE CONFUSING ME METAL SIGN  \
# 0                       False                           False
# 1                       False                           False
# 2                       False                           False
# 3                       False                           False
# 4                       False                           False
#
#    ZINC METAL HEART DECORATION  ZINC WILLIE WINKIE  CANDLE STICK
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
# 3                        False                             False
# 4                        False                             False
#
# [5 rows x 995 columns]
#
#
# Transactions for United Kingdom:
#            1 HANGER    3 TIER   BACK DOOR   BAROQUE   BILLBOARD FONTS DESIGN  \
# 0  False       False    False       False     False                    False
# 1  False       False    False       False     False                    False
# 2  False       False    False       False     False                    False
# 3  False       False    False       False     False                    False
# 4  False       False    False       False     False                    False
#
#     BIRTHDAY CARD   BLUE   BREAKFAST IN BED   CAROUSEL  ...  \
# 0           False  False              False      False  ...
# 1           False  False              False      False  ...
# 2           False  False              False      False  ...
# 3           False  False              False      False  ...
# 4           False  False              False      False  ...
#
#    wrongly coded 20713  wrongly coded 23343  wrongly coded-23343  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
#
#    wrongly marked  wrongly marked 23343  wrongly marked carton 22804  \
# 0           False                 False                        False
# 1           False                 False                        False
# 2           False                 False                        False
# 3           False                 False                        False
# 4           False                 False                        False
#
#    wrongly marked. 23343 in box  wrongly sold (22719) barcode  \
# 0                         False                         False
# 1                         False                         False
# 2                         False                         False
# 3                         False                         False
# 4                         False                         False
#
#    wrongly sold as sets  wrongly sold sets
# 0                 False              False
# 1                 False              False
# 2                 False              False
# 3                 False              False
# 4                 False              False
#
# [5 rows x 4224 columns]

# %% [markdown]
# Next, we applied the FP-Growth algorithm to extract frequent itemsets and association rules for each country's transactions. For a subset of countries, including United Kingdom, France, Germany, and others, we identified frequent itemsets with a minimum support threshold of 0.1, ensuring only the most relevant patterns are included. These frequent itemsets were then sorted by their support values to highlight the most common combinations of items. Additionally, we used the association_rules function to derive meaningful rules, filtering them based on a confidence threshold of 0.8.
#
# Finally, we displayed the frequent itemsets and association rules for each country to gain insights into region-specific shopping patterns.

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

fq_itemsets = {}
fq_rules = {}
# Apply FP-Growth to each country's transactions
for country, transactions in country_transactions.items():
    #if country in {'United Kingdom', 'France', 'Germany', 'Australia', 'Austria', 'Bahrain', 'Belgium'}:
    frequent_itemsets = fpgrowth(transactions, min_support=0.1, use_colnames=True)
    top_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
    rules = association_rules(top_itemsets, metric='confidence', min_threshold=0.8)
    fq_itemsets[country] = frequent_itemsets
    fq_rules[country] = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]

# %%
for country, itemsets in fq_itemsets.items():
    print(f"Frequent itemsets for {country}")
    print(len(itemsets))
    print(itemsets.sort_values(by='support', ascending=False).head(5))
    print("\n")
# Out:
# Frequent itemsets for Australia
# 30
#      support                            itemsets
# 21  0.157895     (RED TOADSTOOL LED NIGHT LIGHT)
# 4   0.157895  (SET OF 3 CAKE TINS PANTRY DESIGN)
# 9   0.140351         (LUNCH BAG SPACEBOY DESIGN)
# 16  0.140351   (ROSES REGENCY TEACUP AND SAUCER)
# 11  0.140351                     (PARTY BUNTING)
#
#
# Frequent itemsets for Belgium
# 70
#      support                                       itemsets
# 0   0.979592                                      (POSTAGE)
# 13  0.387755           (ROUND SNACK BOXES SET OF4 WOODLAND)
# 48  0.387755  (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 6   0.234694                           (SPACEBOY LUNCH BOX)
# 36  0.234694                (POSTAGE, DOLLY GIRL LUNCH BOX)
#
#
# Frequent itemsets for France
# 45
#      support                            itemsets
# 0   0.765306                           (POSTAGE)
# 22  0.188776                (RABBIT NIGHT LIGHT)
# 1   0.181122     (RED TOADSTOOL LED NIGHT LIGHT)
# 10  0.170918  (PLASTERS IN TIN WOODLAND ANIMALS)
# 18  0.168367     (PLASTERS IN TIN CIRCUS PARADE)
#
#
# Frequent itemsets for Germany
# 20
#      support                                       itemsets
# 0   0.818381                                      (POSTAGE)
# 3   0.245077           (ROUND SNACK BOXES SET OF4 WOODLAND)
# 11  0.225383  (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 4   0.157549            (ROUND SNACK BOXES SET OF 4 FRUITS)
# 12  0.150985   (POSTAGE, ROUND SNACK BOXES SET OF 4 FRUITS)
#
#
# Frequent itemsets for Netherlands
# 65
#      support                                    itemsets
# 0   0.389474                                   (POSTAGE)
# 2   0.294737                        (SPACEBOY LUNCH BOX)
# 3   0.263158        (ROUND SNACK BOXES SET OF4 WOODLAND)
# 13  0.231579                      (DOLLY GIRL LUNCH BOX)
# 42  0.221053  (SPACEBOY LUNCH BOX, DOLLY GIRL LUNCH BOX)
#
#
# Frequent itemsets for Norway
# 142
#       support                                     itemsets
# 15   0.555556                                    (POSTAGE)
# 35   0.361111           (SET OF 3 CAKE TINS PANTRY DESIGN)
# 109  0.277778  (SET OF 3 CAKE TINS PANTRY DESIGN, POSTAGE)
# 17   0.277778                   (REGENCY CAKESTAND 3 TIER)
# 78   0.222222          (POSTAGE, REGENCY CAKESTAND 3 TIER)
#
#
# Frequent itemsets for Portugal
# 110
#      support                           itemsets
# 0   0.517241                          (POSTAGE)
# 13  0.241379          (LUNCH BAG RED RETROSPOT)
# 26  0.241379  (RETROSPOT TEA SET CERAMIC 11 PC)
# 25  0.206897     (BAKING SET 9 PIECE RETROSPOT)
# 1   0.206897              (LUNCH BAG CARS BLUE)
#
#
# Frequent itemsets for Spain
# 23
#      support                             itemsets
# 2   0.688889                            (POSTAGE)
# 3   0.244444           (REGENCY CAKESTAND 3 TIER)
# 16  0.188889  (POSTAGE, REGENCY CAKESTAND 3 TIER)
# 8   0.166667             (6 RIBBONS RUSTIC CHARM)
# 9   0.155556           (JAM MAKING SET WITH JARS)
#
#
# Frequent itemsets for Switzerland
# 82
#      support                                           itemsets
# 0   0.574074                                          (POSTAGE)
# 5   0.333333                         (PLASTERS IN TIN SPACEBOY)
# 2   0.314815                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 1   0.314815               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 39  0.240741  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
#
#
# Frequent itemsets for United Kingdom
# 2
#     support                              itemsets
# 0  0.116034  (WHITE HANGING HEART T-LIGHT HOLDER)
# 1  0.103820             (JUMBO BAG RED RETROSPOT)

# %%
for country, rules in fq_rules.items():
    print(f"Association rules for {country}")
    print(len(rules))
    print(rules.head(5))
    print("\n")
# Out:
# Association rules for Australia
# 4
#                     antecedents                   consequents   support  \
# 0    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)  0.105263
# 1  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)  0.105263
# 2          (SPACEBOY LUNCH BOX)        (DOLLY GIRL LUNCH BOX)  0.105263
# 3        (DOLLY GIRL LUNCH BOX)          (SPACEBOY LUNCH BOX)  0.105263
#
#    confidence  lift
# 0         1.0   9.5
# 1         1.0   9.5
# 2         1.0   9.5
# 3         1.0   9.5
#
#
# Association rules for Belgium
# 46
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)                             (POSTAGE)
# 1                (DOLLY GIRL LUNCH BOX)                             (POSTAGE)
# 2                  (SPACEBOY LUNCH BOX)                             (POSTAGE)
# 3   (ROUND SNACK BOXES SET OF 4 FRUITS)                             (POSTAGE)
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#     support  confidence      lift
# 0  0.387755    1.000000  1.020833
# 1  0.234694    1.000000  1.020833
# 2  0.234694    1.000000  1.020833
# 3  0.214286    0.954545  0.974432
# 4  0.183673    0.818182  2.110048
#
#
# Association rules for France
# 22
#                             antecedents consequents   support  confidence  \
# 0                  (RABBIT NIGHT LIGHT)   (POSTAGE)  0.165816    0.878378
# 1       (RED TOADSTOOL LED NIGHT LIGHT)   (POSTAGE)  0.158163    0.873239
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)   (POSTAGE)  0.147959    0.935484
# 3       (PLASTERS IN TIN CIRCUS PARADE)   (POSTAGE)  0.147959    0.878788
# 4    (PLASTERS IN TIN WOODLAND ANIMALS)   (POSTAGE)  0.137755    0.805970
#
#        lift
# 0  1.147748
# 1  1.141033
# 2  1.222366
# 3  1.148283
# 4  1.053134
#
#
# Association rules for Germany
# 10
#                                          antecedents  \
# 0               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 1                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 2                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3       (POSTAGE, ROUND SNACK BOXES SET OF 4 FRUITS)
# 4  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...
#
#                             consequents   support  confidence      lift
# 0                             (POSTAGE)  0.225383    0.919643  1.123735
# 1                             (POSTAGE)  0.150985    0.958333  1.171012
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.131291    0.833333  3.400298
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.124726    0.826087  3.370730
# 4                             (POSTAGE)  0.124726    0.950000  1.160829
#
#
# Association rules for Netherlands
# 27
#                                          antecedents  \
# 0                             (DOLLY GIRL LUNCH BOX)
# 1                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 2  (SPACEBOY LUNCH BOX, ROUND SNACK BOXES SET OF4...
# 3  (DOLLY GIRL LUNCH BOX, ROUND SNACK BOXES SET O...
# 4                    (RED TOADSTOOL LED NIGHT LIGHT)
#
#                             consequents   support  confidence      lift
# 0                  (SPACEBOY LUNCH BOX)  0.221053    0.954545  3.238636
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.157895    0.882353  3.352941
# 2                (DOLLY GIRL LUNCH BOX)  0.157895    0.833333  3.598485
# 3                  (SPACEBOY LUNCH BOX)  0.157895    0.937500  3.180804
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.126316    0.857143  3.257143
#
#
# Association rules for Norway
# 266
#                                          antecedents  \
# 0  (SET OF 3 CAKE TINS PANTRY DESIGN, REGENCY CAK...
# 1                    (CHILDS BREAKFAST SET SPACEBOY)
# 2              (SET OF TEA COFFEE SUGAR TINS PANTRY)
# 3                  (RECIPE BOX PANTRY YELLOW DESIGN)
# 4                (HOT WATER BOTTLE TEA AND SYMPATHY)
#
#                            consequents   support  confidence      lift
# 0                            (POSTAGE)  0.166667    1.000000  1.800000
# 1    (CHILDS BREAKFAST SET DOLLY GIRL)  0.166667    1.000000  4.500000
# 2   (SET OF 3 CAKE TINS PANTRY DESIGN)  0.166667    0.857143  2.373626
# 3  (HOT WATER BOTTLE TEA AND SYMPATHY)  0.138889    0.833333  6.000000
# 4    (RECIPE BOX PANTRY YELLOW DESIGN)  0.138889    1.000000  6.000000
#
#
# Association rules for Portugal
# 120
#                                          antecedents  \
# 0                   (JUMBO BAG PINK VINTAGE PAISLEY)
# 1                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 2                   (JUMBO BAG PINK VINTAGE PAISLEY)
# 3              (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)
# 4  (JUMBO BAG PINK VINTAGE PAISLEY, LUNCH BAG RED...
#
#                            consequents   support  confidence      lift
# 0  (JUMBO SHOPPER VINTAGE RED PAISLEY)  0.155172    1.000000  5.272727
# 1     (JUMBO BAG PINK VINTAGE PAISLEY)  0.155172    0.818182  5.272727
# 2            (LUNCH BAG RED RETROSPOT)  0.137931    0.888889  3.682540
# 3  (JUMBO SHOPPER VINTAGE RED PAISLEY)  0.137931    0.888889  4.686869
# 4  (JUMBO SHOPPER VINTAGE RED PAISLEY)  0.137931    1.000000  5.272727
#
#
# Association rules for Spain
# 6
#                                 antecedents               consequents  \
# 0                  (6 RIBBONS RUSTIC CHARM)                 (POSTAGE)
# 1           (ASSORTED COLOUR BIRD ORNAMENT)                 (POSTAGE)
# 2         (PACK OF 72 RETROSPOT CAKE CASES)                 (POSTAGE)
# 3     (CLASSIC METAL BIRDCAGE PLANT HOLDER)                 (POSTAGE)
# 4  (POSTAGE, ASSORTED COLOUR BIRD ORNAMENT)  (6 RIBBONS RUSTIC CHARM)
#
#     support  confidence      lift
# 0  0.144444    0.866667  1.258065
# 1  0.122222    0.916667  1.330645
# 2  0.122222    1.000000  1.451613
# 3  0.100000    0.900000  1.306452
# 4  0.100000    0.818182  4.909091
#
#
# Association rules for Switzerland
# 29
#                                          antecedents  \
# 0                    (PLASTERS IN TIN CIRCUS PARADE)
# 1                    (PLASTERS IN TIN CIRCUS PARADE)
# 2  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 3  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 4        (PLASTERS IN TIN WOODLAND ANIMALS, POSTAGE)
#
#                           consequents   support  confidence      lift
# 0          (PLASTERS IN TIN SPACEBOY)  0.185185    0.909091  2.727273
# 1  (PLASTERS IN TIN WOODLAND ANIMALS)  0.166667    0.818182  2.598930
# 2          (PLASTERS IN TIN SPACEBOY)  0.148148    0.888889  2.666667
# 3  (PLASTERS IN TIN WOODLAND ANIMALS)  0.148148    0.800000  2.541176
# 4          (PLASTERS IN TIN SPACEBOY)  0.148148    0.800000  2.400000
#
#
# Association rules for United Kingdom
# 0
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %% [markdown]
# To analyze the strength of association rules, we categorize them based on lift: rules with lift > 1 are positively correlated, and those with lift ≤ 1 are negatively correlated. Overall, most of the rules are positively correlated, which is a good sign.

# %%
for country, rules in fq_rules.items():
    # Separate rules based on lift
    positive_corr = rules[rules['lift'] > 1]
    negative_corr = rules[rules['lift'] <= 1]
    
    # Print association rule correlation summary
    print(f"Association rules correlation for country: {country}")
    print(f"Total Rules: {len(rules)}")
    print(f"Positive correlation rules: {len(positive_corr)}")
    print(f"Negative correlation rules: {len(negative_corr)}")
    print("\n")
# Out:
# Association rules correlation for country: Australia
# Total Rules: 4
# Positive correlation rules: 4
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Belgium
# Total Rules: 46
# Positive correlation rules: 44
# Negative correlation rules: 2
#
#
# Association rules correlation for country: France
# Total Rules: 22
# Positive correlation rules: 22
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Germany
# Total Rules: 10
# Positive correlation rules: 10
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Netherlands
# Total Rules: 27
# Positive correlation rules: 27
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Norway
# Total Rules: 266
# Positive correlation rules: 266
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Portugal
# Total Rules: 120
# Positive correlation rules: 120
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Spain
# Total Rules: 6
# Positive correlation rules: 6
# Negative correlation rules: 0
#
#
# Association rules correlation for country: Switzerland
# Total Rules: 29
# Positive correlation rules: 29
# Negative correlation rules: 0
#
#
# Association rules correlation for country: United Kingdom
# Total Rules: 0
# Positive correlation rules: 0
# Negative correlation rules: 0

# %% [markdown]
# # Apriori Algorithm

# %% [markdown]
# The Apriori algorithm is another method for detecting frequent itemsets, leveraging the `apriori` and `association_rules` functions from the `mlxtend` library. In this analysis, we applied the Apriori algorithm to the same subset of countries and used the same minimum support threshold of 0.1. These itemsets were then sorted in descending order of support to identify the most common combinations of items. Additionally, we used the association_rules function to extract meaningful rules from the frequent itemsets, applying a minimum confidence threshold of 0.8 to filter the results.

# %%
from mlxtend.frequent_patterns import apriori, association_rules

apriori_itemsets = {}
apriori_rules = {}

# %%
# Apply Apriori to each country's transactions
for country, transactions in country_transactions.items():
    #if country in {'United Kingdom', 'France', 'Germany', 'Australia', 'Austria', 'Bahrain', 'Belgium'}:
    print(f"Processing Apriori for {country}...\n")
        
    # Generate frequent itemsets using Apriori
    frequent_itemsets = apriori(transactions, min_support=0.1, use_colnames=True)
        
    # Sort itemsets by support in descending order
    top_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
        
    # Generate association rules from the frequent itemsets
    rules = association_rules(top_itemsets, metric='confidence', min_threshold=0.8)
        
    # Store results
    apriori_itemsets[country] = frequent_itemsets
    apriori_rules[country] = rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
# Processing Apriori for Australia...
#
# Processing Apriori for Belgium...
#
# Processing Apriori for France...
#
# Processing Apriori for Germany...
#
# Processing Apriori for Netherlands...
#
# Processing Apriori for Norway...
#
# Processing Apriori for Portugal...
#
# Processing Apriori for Spain...
#
# Processing Apriori for Switzerland...
#
# Processing Apriori for United Kingdom...

# %% [markdown]
# Finally, we stored and displayed the frequent itemsets and association rules for each country, providing insights into purchasing patterns based on the Apriori algorithm.

# %%
# Display results for frequent itemsets
for country, itemsets in apriori_itemsets.items():
    print(f"Frequent itemsets for {country} (Apriori)")
    print(len(itemsets))
    print(itemsets.sort_values(by='support', ascending=False).head(5))
    print("\n")
# Out:
# Frequent itemsets for Australia (Apriori)
# 30
#      support                            itemsets
# 19  0.157895     (RED TOADSTOOL LED NIGHT LIGHT)
# 22  0.157895  (SET OF 3 CAKE TINS PANTRY DESIGN)
# 9   0.140351           (LUNCH BAG RED RETROSPOT)
# 21  0.140351   (ROSES REGENCY TEACUP AND SAUCER)
# 14  0.140351                     (PARTY BUNTING)
#
#
# Frequent itemsets for Belgium (Apriori)
# 70
#      support                                       itemsets
# 17  0.979592                                      (POSTAGE)
# 24  0.387755           (ROUND SNACK BOXES SET OF4 WOODLAND)
# 54  0.387755  (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 34  0.234694                (POSTAGE, DOLLY GIRL LUNCH BOX)
# 56  0.234694                  (POSTAGE, SPACEBOY LUNCH BOX)
#
#
# Frequent itemsets for France (Apriori)
# 45
#      support                            itemsets
# 11  0.765306                           (POSTAGE)
# 12  0.188776                (RABBIT NIGHT LIGHT)
# 14  0.181122     (RED TOADSTOOL LED NIGHT LIGHT)
# 10  0.170918  (PLASTERS IN TIN WOODLAND ANIMALS)
# 8   0.168367     (PLASTERS IN TIN CIRCUS PARADE)
#
#
# Frequent itemsets for Germany (Apriori)
# 20
#      support                                       itemsets
# 5   0.818381                                      (POSTAGE)
# 8   0.245077           (ROUND SNACK BOXES SET OF4 WOODLAND)
# 16  0.225383  (POSTAGE, ROUND SNACK BOXES SET OF4 WOODLAND)
# 7   0.157549            (ROUND SNACK BOXES SET OF 4 FRUITS)
# 15  0.150985   (POSTAGE, ROUND SNACK BOXES SET OF 4 FRUITS)
#
#
# Frequent itemsets for Netherlands (Apriori)
# 65
#      support                                    itemsets
# 22  0.389474                                   (POSTAGE)
# 29  0.294737                        (SPACEBOY LUNCH BOX)
# 26  0.263158        (ROUND SNACK BOXES SET OF4 WOODLAND)
# 8   0.231579                      (DOLLY GIRL LUNCH BOX)
# 34  0.221053  (SPACEBOY LUNCH BOX, DOLLY GIRL LUNCH BOX)
#
#
# Frequent itemsets for Norway (Apriori)
# 142
#      support                                     itemsets
# 34  0.555556                                    (POSTAGE)
# 41  0.361111           (SET OF 3 CAKE TINS PANTRY DESIGN)
# 95  0.277778  (SET OF 3 CAKE TINS PANTRY DESIGN, POSTAGE)
# 39  0.277778                   (REGENCY CAKESTAND 3 TIER)
# 5   0.222222            (CHILDS BREAKFAST SET DOLLY GIRL)
#
#
# Frequent itemsets for Portugal (Apriori)
# 110
#      support                           itemsets
# 25  0.517241                          (POSTAGE)
# 30  0.241379  (RETROSPOT TEA SET CERAMIC 11 PC)
# 14  0.241379          (LUNCH BAG RED RETROSPOT)
# 1   0.206897     (BAKING SET 9 PIECE RETROSPOT)
# 11  0.206897              (LUNCH BAG CARS BLUE)
#
#
# Frequent itemsets for Spain (Apriori)
# 23
#      support                             itemsets
# 8   0.688889                            (POSTAGE)
# 9   0.244444           (REGENCY CAKESTAND 3 TIER)
# 21  0.188889  (POSTAGE, REGENCY CAKESTAND 3 TIER)
# 0   0.166667             (6 RIBBONS RUSTIC CHARM)
# 4   0.155556           (JAM MAKING SET WITH JARS)
#
#
# Frequent itemsets for Switzerland (Apriori)
# 82
#      support                                           itemsets
# 16  0.574074                                          (POSTAGE)
# 13  0.333333                         (PLASTERS IN TIN SPACEBOY)
# 15  0.314815                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 23  0.314815               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 47  0.240741  (PLASTERS IN TIN WOODLAND ANIMALS, PLASTERS IN...
#
#
# Frequent itemsets for United Kingdom (Apriori)
# 2
#     support                              itemsets
# 1  0.116034  (WHITE HANGING HEART T-LIGHT HOLDER)
# 0  0.103820             (JUMBO BAG RED RETROSPOT)

# %%
# Display results for association rules
for country, rules in apriori_rules.items():
    print(f"Association rules for {country} (Apriori)")
    print(len(rules))
    print(rules.head(5))
    print("\n")
# Out:
# Association rules for Australia (Apriori)
# 4
#                     antecedents                   consequents   support  \
# 0    (ALARM CLOCK BAKELIKE RED)  (ALARM CLOCK BAKELIKE GREEN)  0.105263
# 1  (ALARM CLOCK BAKELIKE GREEN)    (ALARM CLOCK BAKELIKE RED)  0.105263
# 2          (SPACEBOY LUNCH BOX)        (DOLLY GIRL LUNCH BOX)  0.105263
# 3        (DOLLY GIRL LUNCH BOX)          (SPACEBOY LUNCH BOX)  0.105263
#
#    confidence  lift
# 0         1.0   9.5
# 1         1.0   9.5
# 2         1.0   9.5
# 3         1.0   9.5
#
#
# Association rules for Belgium (Apriori)
# 46
#                             antecedents                           consequents  \
# 0  (ROUND SNACK BOXES SET OF4 WOODLAND)                             (POSTAGE)
# 1                (DOLLY GIRL LUNCH BOX)                             (POSTAGE)
# 2                  (SPACEBOY LUNCH BOX)                             (POSTAGE)
# 3   (ROUND SNACK BOXES SET OF 4 FRUITS)                             (POSTAGE)
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#     support  confidence      lift
# 0  0.387755    1.000000  1.020833
# 1  0.234694    1.000000  1.020833
# 2  0.234694    1.000000  1.020833
# 3  0.214286    0.954545  0.974432
# 4  0.183673    0.818182  2.110048
#
#
# Association rules for France (Apriori)
# 22
#                             antecedents consequents   support  confidence  \
# 0                  (RABBIT NIGHT LIGHT)   (POSTAGE)  0.165816    0.878378
# 1       (RED TOADSTOOL LED NIGHT LIGHT)   (POSTAGE)  0.158163    0.873239
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)   (POSTAGE)  0.147959    0.935484
# 3       (PLASTERS IN TIN CIRCUS PARADE)   (POSTAGE)  0.147959    0.878788
# 4    (PLASTERS IN TIN WOODLAND ANIMALS)   (POSTAGE)  0.137755    0.805970
#
#        lift
# 0  1.147748
# 1  1.141033
# 2  1.222366
# 3  1.148283
# 4  1.053134
#
#
# Association rules for Germany (Apriori)
# 10
#                                          antecedents  \
# 0               (ROUND SNACK BOXES SET OF4 WOODLAND)
# 1                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 2                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 3  (ROUND SNACK BOXES SET OF 4 FRUITS, ROUND SNAC...
# 4       (POSTAGE, ROUND SNACK BOXES SET OF 4 FRUITS)
#
#                             consequents   support  confidence      lift
# 0                             (POSTAGE)  0.225383    0.919643  1.123735
# 1                             (POSTAGE)  0.150985    0.958333  1.171012
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.131291    0.833333  3.400298
# 3                             (POSTAGE)  0.124726    0.950000  1.160829
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.124726    0.826087  3.370730
#
#
# Association rules for Netherlands (Apriori)
# 27
#                                          antecedents  \
# 0                             (DOLLY GIRL LUNCH BOX)
# 1                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 2  (SPACEBOY LUNCH BOX, ROUND SNACK BOXES SET OF4...
# 3  (DOLLY GIRL LUNCH BOX, ROUND SNACK BOXES SET O...
# 4                         (PLASTERS IN TIN SPACEBOY)
#
#                             consequents   support  confidence      lift
# 0                  (SPACEBOY LUNCH BOX)  0.221053    0.954545  3.238636
# 1  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.157895    0.882353  3.352941
# 2                (DOLLY GIRL LUNCH BOX)  0.157895    0.833333  3.598485
# 3                  (SPACEBOY LUNCH BOX)  0.157895    0.937500  3.180804
# 4  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.126316    1.000000  3.800000
#
#
# Association rules for Norway (Apriori)
# 266
#                                          antecedents  \
# 0              (SET OF TEA COFFEE SUGAR TINS PANTRY)
# 1                    (CHILDS BREAKFAST SET SPACEBOY)
# 2  (SET OF 3 CAKE TINS PANTRY DESIGN, REGENCY CAK...
# 3                    (RED TOADSTOOL LED NIGHT LIGHT)
# 4                    (CHILDS BREAKFAST SET SPACEBOY)
#
#                           consequents   support  confidence      lift
# 0  (SET OF 3 CAKE TINS PANTRY DESIGN)  0.166667    0.857143  2.373626
# 1   (CHILDS BREAKFAST SET DOLLY GIRL)  0.166667    1.000000  4.500000
# 2                           (POSTAGE)  0.166667    1.000000  1.800000
# 3     (CHILDS BREAKFAST SET SPACEBOY)  0.138889    0.833333  5.000000
# 4     (RED TOADSTOOL LED NIGHT LIGHT)  0.138889    0.833333  5.000000
#
#
# Association rules for Portugal (Apriori)
# 120
#                                          antecedents  \
# 0                   (JUMBO BAG PINK VINTAGE PAISLEY)
# 1                (JUMBO SHOPPER VINTAGE RED PAISLEY)
# 2              (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)
# 3  (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO SHOPPER...
# 4  (JUMBO BAG PINK VINTAGE PAISLEY, JUMBO BAG SCA...
#
#                              consequents   support  confidence      lift
# 0    (JUMBO SHOPPER VINTAGE RED PAISLEY)  0.155172    1.000000  5.272727
# 1       (JUMBO BAG PINK VINTAGE PAISLEY)  0.155172    0.818182  5.272727
# 2    (JUMBO SHOPPER VINTAGE RED PAISLEY)  0.137931    0.888889  4.686869
# 3  (JUMBO BAG SCANDINAVIAN BLUE PAISLEY)  0.137931    0.888889  5.728395
# 4    (JUMBO SHOPPER VINTAGE RED PAISLEY)  0.137931    1.000000  5.272727
#
#
# Association rules for Spain (Apriori)
# 6
#                                 antecedents               consequents  \
# 0                  (6 RIBBONS RUSTIC CHARM)                 (POSTAGE)
# 1           (ASSORTED COLOUR BIRD ORNAMENT)                 (POSTAGE)
# 2         (PACK OF 72 RETROSPOT CAKE CASES)                 (POSTAGE)
# 3     (CLASSIC METAL BIRDCAGE PLANT HOLDER)                 (POSTAGE)
# 4  (POSTAGE, ASSORTED COLOUR BIRD ORNAMENT)  (6 RIBBONS RUSTIC CHARM)
#
#     support  confidence      lift
# 0  0.144444    0.866667  1.258065
# 1  0.122222    0.916667  1.330645
# 2  0.122222    1.000000  1.451613
# 3  0.100000    0.900000  1.306452
# 4  0.100000    0.818182  4.909091
#
#
# Association rules for Switzerland (Apriori)
# 29
#                                          antecedents  \
# 0                    (PLASTERS IN TIN CIRCUS PARADE)
# 1                    (PLASTERS IN TIN CIRCUS PARADE)
# 2                    (RED TOADSTOOL LED NIGHT LIGHT)
# 3                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 4  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
#
#                             consequents   support  confidence      lift
# 0            (PLASTERS IN TIN SPACEBOY)  0.185185    0.909091  2.727273
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)  0.166667    0.818182  2.598930
# 2  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.148148    1.000000  3.176471
# 3  (ROUND SNACK BOXES SET OF4 WOODLAND)  0.148148    0.888889  2.823529
# 4            (PLASTERS IN TIN SPACEBOY)  0.148148    0.888889  2.666667
#
#
# Association rules for United Kingdom (Apriori)
# 0
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %% [markdown]
# Once we run through all the calculations, we observe that the results of the Apriori algorithm matches the results obtained by FP Growth for all countries.

# %% [markdown]
# # KNOWLEDGE REPRESENTATION

# %% [markdown]
# At the final stage of Knowledge Discovery in Databases (KDD),
# the knowledge representation is captured in a graph database,
# which enables better insight and visualization of the discovered patterns.
# In this step, we store the association rules discovered by algorithms such as
# Apriori in a Neo4j graph database.
#
# In the provided code, a connection to the Neo4j database is established,
# and a dynamic structure is created for storing countries,
# association rules (antecedents and consequents), and their relationships,
# such as `HAS_RULE` and `RESULTS_INTO`.
# This allows you to represent associations between items (antecedents and consequents)
# for specific countries with their
# corresponding support, confidence, and lift values.
#
# The graph is visualized using the `networkx` library and the `matplotlib` library,
# which provides a clear and interactive way
# to explore the relationships. Each rule is visualized as a directed edge,
# with the support, confidence, and lift values labeled on the edges,
# giving a visual overview of the strength and reliability of each rule.
# This representation helps in understanding the relationships between items in a country
# and can further be used for different use cases like recommendation systems or market basket analysis.
#
# Here's a breakdown of the core steps involved in the code:
#
# 1. **Neo4j Graph Database Connection**: Establishing a connection to a Neo4j database where the rules will be stored.
# 2. **Storing Rules**: The `create_rule` function dynamically creates country nodes, antecedent nodes, and consequent nodes, and links them with relationships such as `HAS_RULE` and `RESULTS_INTO`, with properties for support, confidence, and lift.
# 3. **Visualizing the Graph**: The `visualize_graph` function generates a visual representation of the graph using `networkx`, highlighting the rules between antecedents and consequents.
# 4. **Clearing the Database**: Before creating new rules, the `clear_database` function deletes any existing rules and nodes, ensuring the graph remains up-to-date with the latest rules.
#
# This step completes the KDD pipeline by transforming raw data into actionable insights represented as knowledge in a graph structure, ready for further analysis or decision-making.
#
# ### Why this is better than traditional storage:
# - **Efficient Relationship Modeling**: Unlike traditional relational databases, which struggle with complex, many-to-many relationships, Neo4j is optimized for handling and querying connected data. It allows for intuitive representation and querying of relationships, making it easier to uncover hidden patterns and associations between items.
#
# - **Scalability and Flexibility**: As the data grows, graph databases like Neo4j efficiently scale and adapt to complex structures, without the need for expensive joins or cumbersome relational tables. This flexibility is ideal for dynamic and evolving data, like association rules, where relationships are central to the analysis.
#
# These features enable faster, more efficient querying and provide deeper insights into the data compared to traditional row-based storage systems.

# %%
from neo4j import GraphDatabase
import networkx as nx
import matplotlib.pyplot as plt

# Neo4j connection details
uri = "neo4j+s://27f471e5.databases.neo4j.io"  # Aura instance URI
username = "neo4j"  # Neo4j username
password = "EI5gKZQ6XT0y4bMRMej9orSxnkEP-Xc77lqZLH6Hkac"  # Neo4j password

# Initialize the driver
driver = GraphDatabase.driver(uri, auth=(username, password))

# Function to create a country node (dynamic)
def create_country(tx, country_name):
    tx.run("MERGE (ct:Country {name: $country_name})", country_name=country_name)

# Function to create rules based on the given antecedent, consequent, and properties
def create_rule(tx, country_name, antecedent_items, consequent_items, support, confidence, lift):
    tx.run(
        """
        MERGE (a:Antecedent {items: $antecedent_items})
        MERGE (c:Consequent {items: $consequent_items})
        WITH a, c
        MATCH (ct:Country {name: $country_name})
        MERGE (ct)-[:HAS_RULE]->(a)-[:RESULTS_INTO {support: $support, confidence: $confidence, lift: $lift}]->(c)
        """,
        antecedent_items=antecedent_items,
        consequent_items=consequent_items,
        support=support,
        confidence=confidence,
        lift=lift,
        country_name=country_name
    )

# Function to visualize the graph and save as an image
def visualize_graph(G, filename="graph.png"):
    pos = nx.spring_layout(G)  # Positioning nodes
    plt.figure(figsize=(12, 12))  # Adjust figure size
    nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=3000, font_size=10, font_weight='bold', edge_color='gray')
    
    # Draw edge labels (support, confidence, lift)
    edge_labels = nx.get_edge_attributes(G, 'support')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    
    # Save the graph as an image
    plt.title("Association Rules Graph")
    plt.savefig(filename)
    plt.close()
    
def clear_database(tx):
    # Delete HAS_RULE relationships
    tx.run("MATCH (a)-[re:HAS_RULE]-(b) DELETE re")
    # Delete RESULTS_INTO relationships
    tx.run("MATCH (a)-[re:RESULTS_INTO]-(b) DELETE re")
    # Delete all nodes
    tx.run("MATCH (n) DELETE n")
    
# Function to fetch rules for a specific country
def fetch_rules(tx, country_name):
    query = """
    MATCH (ct:Country {name: $country_name})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
    RETURN ct, a, r1, r2, c
    """
    result = tx.run(query, country_name=country_name)
    return [
        {"antecedent": record["a"].get("items"), "consequent": record["c"].get("items"), 
         "support": record["r2"].get("support"), "confidence": record["r2"].get("confidence"), "lift": record["r2"].get("lift")}
        for record in result
    ]

# Function to create a graph representation of the rules
def create_graph(rules):
    G = nx.DiGraph()  # Directed graph
    
    # Add nodes and edges
    for rule in rules:
        antecedent = str(rule['antecedent'])
        consequent = str(rule['consequent'])
        G.add_node(antecedent, type='Antecedent')
        G.add_node(consequent, type='Consequent')
        G.add_edge(
            antecedent, consequent,
            support=rule['support'], confidence=rule['confidence'], lift=rule['lift']
        )
    
    return G

# Function to visualize the graph and save it as an image
def visualize_graph(G, filename="graph.png"):
    pos = nx.spring_layout(G)  # Positioning nodes
    plt.figure(figsize=(12, 12))  # Adjust figure size
    nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=3000, font_size=10, font_weight='bold', edge_color='gray')
    
    # Draw edge labels (support, confidence, lift)
    edge_labels = {
        (u, v): f"Supp: {d['support']:.2f}, Conf: {d['confidence']:.2f}, Lift: {d['lift']:.2f}"
        for u, v, d in G.edges(data=True)
    }
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    
    # Save the graph as an image
    plt.title("Association Rules Graph")
    plt.savefig(filename)
    plt.close()

# %%
with driver.session() as session:
    # Clear the database in the specified sequence
    session.execute_write(clear_database)
    print("All nodes and relationships deleted in sequence.")
# Out:
# All nodes and relationships deleted in sequence.

# %%
for country, rules in fq_rules.items():
    print(f"Association rules for {country} in graph database - Neo4j")
    
    # Initialize the list to hold the association rules
    association_rules = []
    
    rules = rules.head(5)

    # Iterate over each row in the DataFrame
    for index, row in rules.iterrows():
        # Create a dictionary for each rule and append it to the list
        rule = {
            'antecedents': row['antecedents'],
            'consequents': row['consequents'],
            'support': row['support'],
            'confidence': row['confidence'],
            'lift': row['lift']
        }
        association_rules.append(rule)
    
    # Display the result
    print(association_rules)
    print("\n")
    
    country_name = country
    
    with driver.session() as session:
        # Create the country node
        session.execute_write(create_country, country_name)
    
        # Loop through the association_rules array and create each rule
        for rule in association_rules:
            antecedents = list(rule['antecedents'])
            consequents = list(rule['consequents'])
            support = rule['support']
            confidence = rule['confidence']
            lift = rule['lift']
            
            # Create the rule in the database with the dynamic country name
            session.execute_write(create_rule, country_name, antecedents, consequents, support, confidence, lift)
        
        # Fetch rules for the specified country
        rules = session.execute_read(fetch_rules, country_name)
    
        # Create a graph from the fetched rules
        G = create_graph(rules)
        
        # Visualize the graph and save the image
        visualize_graph(G, filename=f"association_rules_{country_name}.png")
        
        print(f"Graph image saved as 'association_rules_{country_name}.png'")
# Out:
# Association rules for Australia in graph database - Neo4j
# [{'antecedents': frozenset({'ALARM CLOCK BAKELIKE RED'}), 'consequents': frozenset({'ALARM CLOCK BAKELIKE GREEN'}), 'support': 0.10526315789473684, 'confidence': 1.0, 'lift': 9.5}, {'antecedents': frozenset({'ALARM CLOCK BAKELIKE GREEN'}), 'consequents': frozenset({'ALARM CLOCK BAKELIKE RED'}), 'support': 0.10526315789473684, 'confidence': 1.0, 'lift': 9.5}, {'antecedents': frozenset({'SPACEBOY LUNCH BOX'}), 'consequents': frozenset({'DOLLY GIRL LUNCH BOX'}), 'support': 0.10526315789473684, 'confidence': 1.0, 'lift': 9.5}, {'antecedents': frozenset({'DOLLY GIRL LUNCH BOX'}), 'consequents': frozenset({'SPACEBOY LUNCH BOX'}), 'support': 0.10526315789473684, 'confidence': 1.0, 'lift': 9.5}]
#
#
# Graph image saved as 'association_rules_Australia.png'
# Association rules for Belgium in graph database - Neo4j
# [{'antecedents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.3877551020408163, 'confidence': 1.0, 'lift': 1.0208333333333333}, {'antecedents': frozenset({'DOLLY GIRL LUNCH BOX'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.23469387755102042, 'confidence': 1.0, 'lift': 1.0208333333333333}, {'antecedents': frozenset({'SPACEBOY LUNCH BOX'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.23469387755102042, 'confidence': 1.0, 'lift': 1.0208333333333333}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.21428571428571427, 'confidence': 0.9545454545454545, 'lift': 0.9744318181818181}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}), 'consequents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'support': 0.1836734693877551, 'confidence': 0.8181818181818182, 'lift': 2.110047846889952}]
#
#
# Graph image saved as 'association_rules_Belgium.png'
# Association rules for France in graph database - Neo4j
# [{'antecedents': frozenset({'RABBIT NIGHT LIGHT'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.16581632653061223, 'confidence': 0.8783783783783784, 'lift': 1.1477477477477478}, {'antecedents': frozenset({'RED TOADSTOOL LED NIGHT LIGHT'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.15816326530612246, 'confidence': 0.8732394366197184, 'lift': 1.1410328638497653}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.14795918367346939, 'confidence': 0.9354838709677419, 'lift': 1.2223655913978495}, {'antecedents': frozenset({'PLASTERS IN TIN CIRCUS PARADE'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.14795918367346939, 'confidence': 0.8787878787878788, 'lift': 1.1482828282828283}, {'antecedents': frozenset({'PLASTERS IN TIN WOODLAND ANIMALS'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.1377551020408163, 'confidence': 0.8059701492537313, 'lift': 1.053134328358209}]
#
#
# Graph image saved as 'association_rules_France.png'
# Association rules for Germany in graph database - Neo4j
# [{'antecedents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.22538293216630198, 'confidence': 0.9196428571428572, 'lift': 1.1237347211611919}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.15098468271334792, 'confidence': 0.9583333333333333, 'lift': 1.1710115864527628}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}), 'consequents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'support': 0.13129102844638948, 'confidence': 0.8333333333333333, 'lift': 3.400297619047619}, {'antecedents': frozenset({'POSTAGE', 'ROUND SNACK BOXES SET OF 4 FRUITS'}), 'consequents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'support': 0.12472647702407003, 'confidence': 0.8260869565217391, 'lift': 3.3707298136645965}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS', 'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.12472647702407003, 'confidence': 0.9500000000000001, 'lift': 1.1608288770053476}]
#
#
# Graph image saved as 'association_rules_Germany.png'
# Association rules for Netherlands in graph database - Neo4j
# [{'antecedents': frozenset({'DOLLY GIRL LUNCH BOX'}), 'consequents': frozenset({'SPACEBOY LUNCH BOX'}), 'support': 0.22105263157894736, 'confidence': 0.9545454545454545, 'lift': 3.2386363636363638}, {'antecedents': frozenset({'ROUND SNACK BOXES SET OF 4 FRUITS'}), 'consequents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'support': 0.15789473684210525, 'confidence': 0.8823529411764706, 'lift': 3.3529411764705883}, {'antecedents': frozenset({'SPACEBOY LUNCH BOX', 'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'consequents': frozenset({'DOLLY GIRL LUNCH BOX'}), 'support': 0.15789473684210525, 'confidence': 0.8333333333333333, 'lift': 3.598484848484848}, {'antecedents': frozenset({'DOLLY GIRL LUNCH BOX', 'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'consequents': frozenset({'SPACEBOY LUNCH BOX'}), 'support': 0.15789473684210525, 'confidence': 0.9375, 'lift': 3.1808035714285716}, {'antecedents': frozenset({'RED TOADSTOOL LED NIGHT LIGHT'}), 'consequents': frozenset({'ROUND SNACK BOXES SET OF4 WOODLAND'}), 'support': 0.12631578947368421, 'confidence': 0.8571428571428572, 'lift': 3.2571428571428576}]
#
#
# Graph image saved as 'association_rules_Netherlands.png'
# Association rules for Norway in graph database - Neo4j
# [{'antecedents': frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN', 'REGENCY CAKESTAND 3 TIER'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.16666666666666666, 'confidence': 1.0, 'lift': 1.7999999999999998}, {'antecedents': frozenset({'CHILDS BREAKFAST SET SPACEBOY'}), 'consequents': frozenset({'CHILDS BREAKFAST SET DOLLY GIRL'}), 'support': 0.16666666666666666, 'confidence': 1.0, 'lift': 4.5}, {'antecedents': frozenset({'SET OF TEA COFFEE SUGAR TINS PANTRY'}), 'consequents': frozenset({'SET OF 3 CAKE TINS PANTRY DESIGN'}), 'support': 0.16666666666666666, 'confidence': 0.8571428571428571, 'lift': 2.3736263736263736}, {'antecedents': frozenset({'RECIPE BOX PANTRY YELLOW DESIGN'}), 'consequents': frozenset({'HOT WATER BOTTLE TEA AND SYMPATHY'}), 'support': 0.1388888888888889, 'confidence': 0.8333333333333334, 'lift': 6.0}, {'antecedents': frozenset({'HOT WATER BOTTLE TEA AND SYMPATHY'}), 'consequents': frozenset({'RECIPE BOX PANTRY YELLOW DESIGN'}), 'support': 0.1388888888888889, 'confidence': 1.0, 'lift': 6.0}]
#
#
# Graph image saved as 'association_rules_Norway.png'
# Association rules for Portugal in graph database - Neo4j
# [{'antecedents': frozenset({'JUMBO BAG PINK VINTAGE PAISLEY'}), 'consequents': frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY'}), 'support': 0.15517241379310345, 'confidence': 1.0, 'lift': 5.272727272727273}, {'antecedents': frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY'}), 'consequents': frozenset({'JUMBO BAG PINK VINTAGE PAISLEY'}), 'support': 0.15517241379310345, 'confidence': 0.8181818181818182, 'lift': 5.2727272727272725}, {'antecedents': frozenset({'JUMBO BAG PINK VINTAGE PAISLEY'}), 'consequents': frozenset({'LUNCH BAG RED RETROSPOT'}), 'support': 0.13793103448275862, 'confidence': 0.8888888888888888, 'lift': 3.6825396825396823}, {'antecedents': frozenset({'JUMBO BAG SCANDINAVIAN BLUE PAISLEY'}), 'consequents': frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY'}), 'support': 0.13793103448275862, 'confidence': 0.8888888888888888, 'lift': 4.686868686868687}, {'antecedents': frozenset({'JUMBO BAG PINK VINTAGE PAISLEY', 'LUNCH BAG RED RETROSPOT'}), 'consequents': frozenset({'JUMBO SHOPPER VINTAGE RED PAISLEY'}), 'support': 0.13793103448275862, 'confidence': 1.0, 'lift': 5.272727272727273}]
#
#
# Graph image saved as 'association_rules_Portugal.png'
# Association rules for Spain in graph database - Neo4j
# [{'antecedents': frozenset({'6 RIBBONS RUSTIC CHARM'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.14444444444444443, 'confidence': 0.8666666666666666, 'lift': 1.2580645161290323}, {'antecedents': frozenset({'ASSORTED COLOUR BIRD ORNAMENT'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.12222222222222222, 'confidence': 0.9166666666666666, 'lift': 1.3306451612903225}, {'antecedents': frozenset({'PACK OF 72 RETROSPOT CAKE CASES'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.12222222222222222, 'confidence': 1.0, 'lift': 1.4516129032258065}, {'antecedents': frozenset({'CLASSIC METAL BIRDCAGE PLANT HOLDER'}), 'consequents': frozenset({'POSTAGE'}), 'support': 0.1, 'confidence': 0.9000000000000001, 'lift': 1.306451612903226}, {'antecedents': frozenset({'POSTAGE', 'ASSORTED COLOUR BIRD ORNAMENT'}), 'consequents': frozenset({'6 RIBBONS RUSTIC CHARM'}), 'support': 0.1, 'confidence': 0.8181818181818182, 'lift': 4.90909090909091}]
#
#
# Graph image saved as 'association_rules_Spain.png'
# Association rules for Switzerland in graph database - Neo4j
# [{'antecedents': frozenset({'PLASTERS IN TIN CIRCUS PARADE'}), 'consequents': frozenset({'PLASTERS IN TIN SPACEBOY'}), 'support': 0.18518518518518517, 'confidence': 0.9090909090909091, 'lift': 2.7272727272727275}, {'antecedents': frozenset({'PLASTERS IN TIN CIRCUS PARADE'}), 'consequents': frozenset({'PLASTERS IN TIN WOODLAND ANIMALS'}), 'support': 0.16666666666666666, 'confidence': 0.8181818181818182, 'lift': 2.5989304812834226}, {'antecedents': frozenset({'PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN WOODLAND ANIMALS'}), 'consequents': frozenset({'PLASTERS IN TIN SPACEBOY'}), 'support': 0.14814814814814814, 'confidence': 0.8888888888888888, 'lift': 2.6666666666666665}, {'antecedents': frozenset({'PLASTERS IN TIN CIRCUS PARADE', 'PLASTERS IN TIN SPACEBOY'}), 'consequents': frozenset({'PLASTERS IN TIN WOODLAND ANIMALS'}), 'support': 0.14814814814814814, 'confidence': 0.8, 'lift': 2.541176470588235}, {'antecedents': frozenset({'PLASTERS IN TIN WOODLAND ANIMALS', 'POSTAGE'}), 'consequents': frozenset({'PLASTERS IN TIN SPACEBOY'}), 'support': 0.14814814814814814, 'confidence': 0.8, 'lift': 2.4000000000000004}]
#
#
# Graph image saved as 'association_rules_Switzerland.png'
# Association rules for United Kingdom in graph database - Neo4j
# []
#
#
# Graph image saved as 'association_rules_United Kingdom.png'

# %% [markdown]
# Graph images are particularly not getting saved very well, and this is something we couldn't handle effectively. However, you can easily view the graph database's contents and experiment with it directly by following these steps:
#
# **Steps to explore the graph data:**
#
# 1. **Visit the Neo4j Browser** at [this link](https://27f471e5.databases.neo4j.io/browser/).
#
# 2. **Login details:**
#    - **Username**: `neo4j`
#    - **Password**: `EI5gKZQ6XT0y4bMRMej9orSxnkEP-Xc77lqZLH6Hkac`
#
# 3. **Wait for 60 seconds** before connecting to the database, or you can log in to [Neo4j Console](https://console.neo4j.io) to ensure that your Aura instance is available and ready to use.
#
# 4. **Use the following Cypher queries** for each country to view their respective association rule graphs. These queries will return nodes and relationships representing the association rules:
#
# ### Queries for Graph Representation:
#
# - **Australia**:
#   ```cypher
#   MATCH (ct:Country {name: 'Australia'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Belgium**:
#   ```cypher
#   MATCH (ct:Country {name: 'Belgium'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **France**:
#   ```cypher
#   MATCH (ct:Country {name: 'France'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Germany**:
#   ```cypher
#   MATCH (ct:Country {name: 'Germany'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Netherlands**:
#   ```cypher
#   MATCH (ct:Country {name: 'Netherlands'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Norway**:
#   ```cypher
#   MATCH (ct:Country {name: 'Norway'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Portugal**:
#   ```cypher
#   MATCH (ct:Country {name: 'Portugal'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Spain**:
#   ```cypher
#   MATCH (ct:Country {name: 'Spain'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **Switzerland**:
#   ```cypher
#   MATCH (ct:Country {name: 'Switzerland'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# - **United Kingdom**:
#   ```cypher
#   MATCH (ct:Country {name: 'United Kingdom'})-[r1:HAS_RULE]->(a:Antecedent)-[r2:RESULTS_INTO]->(c:Consequent)
#   RETURN ct, a, r1, r2, c
#   ```
#
# ---
#
# These queries will help you visualize the relationship between `Country`, `Antecedent`, and `Consequent` nodes, showing how the association rules are structured for each country.
#
# ### Potential Use Cases for the Knowledge Graphs:
# These knowledge graphs could be utilized for various purposes such as:
#
# - **Trend Analysis**: Compare association rules across different countries.
# - **Product Recommendations**: Discover frequently bought items in different countries and make recommendations.
# - **Data-Driven Decisions**: Utilize association rules to inform strategic decisions.
# - **Visual Insights**: Present graph-based insights for stakeholders to interpret complex data visually.
#
# By following the above steps, you can explore and analyze the data directly in Neo4j's browser and leverage it for deeper analysis or further use cases.

# %%
# Close the driver
driver.close()
